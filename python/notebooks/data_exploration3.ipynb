# %%
### FIRST add the token from running the command in powershell
# setx OPENAI_API_KEY "*****"
import openai
import os
### THEN, test if it is actually there in the environment
print(os.getenv("OPENAI_API_KEY"))

# %%
## FOR GOOGLE
# [Environment]::SetEnvironmentVariable("GOOGLE_API_KEY", "your_actual_key_here", "User")

# to make sure it is recognized, close the VS code, open again and run this in powershell
# $env:GOOGLE_API_KEY

# %%
import google.genai
print(google.genai.__version__)
# Out:
# 1.55.0
